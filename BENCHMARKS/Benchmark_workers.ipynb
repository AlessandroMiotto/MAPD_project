# %% [markdown]
# # Benchmarking 2
#
# Another important factor influencing system performance is the **cluster configuration**.
# In particular, the **number of workers** plays a central role in determining the computation speed of the algorithms, as it directly affects the degree of parallelization that can be achieved.
#
# In the following experiments, we keep both the dataset and the partition size fixed, while varying the number of workers.
# This allows us to isolate and study how performance changes as we scale the cluster.

# %%
from functions import cholesky_tsqr, direct_tsqr, indirect_tsqr     # Import the functions

# %%
import time
from time import sleep
from dask.distributed import Client, LocalCluster, wait
import numpy as np
import dask.array as da
import dask
from scipy.linalg import solve_triangular 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Local setup
#
# For academic purposes, and to showcase some core Dask functionalities (e.g., the `cluster.scale()` method), we begin by working locally on a smaller dataset.
# This serves as a foundation for the more extensive study that will later be carried out on the Virtual Machine (VM) hosted on Cloud Veneto.
#
# In the local setup, we create a cluster with 4 processes: **3 workers** that handle computations and **1 scheduler** that coordinates them.

# %%
cluster = LocalCluster(n_workers=4, threads_per_worker=1)
client = Client(cluster)

print("Dashboard:", client.dashboard_link)
# Out:
# /home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 40579 instead
#   warnings.warn(
# Dashboard: http://127.0.0.1:40579/status
# 2025-09-17 22:29:41,157 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:29:41,455 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:29:41,690 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:29:41,896 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:29:42,146 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:29:42,662 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:29:42,881 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:29:43,079 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:29:45,891 - distributed.core - ERROR - Exception while handling op register-client
# Traceback (most recent call last):
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 834, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5984, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 917, in handle_stream
#     handler(**merge(extra, msg))
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5634, in stimulus_cancel
#     self.stimulus_cancel(
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5643, in stimulus_cancel
#     assert ts.who_wants
#            ^^^^^^^^^^^^
# AssertionError
# Task exception was never retrieved
# future: <Task finished name='Task-409' coro=<Server._handle_comm() done, defined at /home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py:740> exception=AssertionError()>
# Traceback (most recent call last):
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 834, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5984, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 917, in handle_stream
#     handler(**merge(extra, msg))
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5634, in stimulus_cancel
#     self.stimulus_cancel(
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5643, in stimulus_cancel
#     assert ts.who_wants
#            ^^^^^^^^^^^^
# AssertionError
# 2025-09-17 22:29:47,325 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:29:47,548 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:29:47,956 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:29:48,833 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:29:49,033 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:29:49,250 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:29:49,454 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:29:52,427 - distributed.core - ERROR - Exception while handling op register-client
# Traceback (most recent call last):
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 834, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5984, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 917, in handle_stream
#     handler(**merge(extra, msg))
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5634, in stimulus_cancel
#     self.stimulus_cancel(
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5643, in stimulus_cancel
#     assert ts.who_wants
#            ^^^^^^^^^^^^
# AssertionError
# Task exception was never retrieved
# future: <Task finished name='Task-27000' coro=<Server._handle_comm() done, defined at /home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py:740> exception=AssertionError()>
# Traceback (most recent call last):
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 834, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5984, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 917, in handle_stream
#     handler(**merge(extra, msg))
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5634, in stimulus_cancel
#     self.stimulus_cancel(
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5643, in stimulus_cancel
#     assert ts.who_wants
#            ^^^^^^^^^^^^
# AssertionError
# 2025-09-17 22:29:56,337 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:29:56,558 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:29:56,824 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:29:57,058 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:29:57,299 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:29:57,506 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:29:57,716 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:29:57,926 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:29:58,149 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:29:58,348 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:30:01,135 - distributed.core - ERROR - Exception while handling op register-client
# Traceback (most recent call last):
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 834, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5984, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 917, in handle_stream
#     handler(**merge(extra, msg))
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5634, in stimulus_cancel
#     self.stimulus_cancel(
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5643, in stimulus_cancel
#     assert ts.who_wants
#            ^^^^^^^^^^^^
# AssertionError
# Task exception was never retrieved
# future: <Task finished name='Task-30088' coro=<Server._handle_comm() done, defined at /home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py:740> exception=AssertionError()>
# Traceback (most recent call last):
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 834, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5984, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 917, in handle_stream
#     handler(**merge(extra, msg))
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5634, in stimulus_cancel
#     self.stimulus_cancel(
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5643, in stimulus_cancel
#     assert ts.who_wants
#            ^^^^^^^^^^^^
# AssertionError
# 2025-09-17 22:30:09,028 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:30:09,246 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:30:09,677 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:30:10,702 - distributed.core - ERROR - Exception while handling op register-client
# Traceback (most recent call last):
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 834, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5984, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 917, in handle_stream
#     handler(**merge(extra, msg))
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5634, in stimulus_cancel
#     self.stimulus_cancel(
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5643, in stimulus_cancel
#     assert ts.who_wants
#            ^^^^^^^^^^^^
# AssertionError
# Task exception was never retrieved
# future: <Task finished name='Task-33946' coro=<Server._handle_comm() done, defined at /home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py:740> exception=AssertionError()>
# Traceback (most recent call last):
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 834, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5984, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 917, in handle_stream
#     handler(**merge(extra, msg))
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5634, in stimulus_cancel
#     self.stimulus_cancel(
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5643, in stimulus_cancel
#     assert ts.who_wants
#            ^^^^^^^^^^^^
# AssertionError
# 2025-09-17 22:30:12,129 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:30:12,343 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:30:12,553 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:30:13,697 - distributed.core - ERROR - Exception while handling op register-client
# Traceback (most recent call last):
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 834, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5984, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 917, in handle_stream
#     handler(**merge(extra, msg))
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5634, in stimulus_cancel
#     self.stimulus_cancel(
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5643, in stimulus_cancel
#     assert ts.who_wants
#            ^^^^^^^^^^^^
# AssertionError
# Task exception was never retrieved
# future: <Task finished name='Task-36675' coro=<Server._handle_comm() done, defined at /home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py:740> exception=AssertionError()>
# Traceback (most recent call last):
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 834, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5984, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 917, in handle_stream
#     handler(**merge(extra, msg))
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5634, in stimulus_cancel
#     self.stimulus_cancel(
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5643, in stimulus_cancel
#     assert ts.who_wants
#            ^^^^^^^^^^^^
# AssertionError
# 2025-09-17 22:30:15,374 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:30:15,614 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:30:16,637 - distributed.core - ERROR - Exception while handling op register-client
# Traceback (most recent call last):
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 834, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5984, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 917, in handle_stream
#     handler(**merge(extra, msg))
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5634, in stimulus_cancel
#     self.stimulus_cancel(
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5643, in stimulus_cancel
#     assert ts.who_wants
#            ^^^^^^^^^^^^
# AssertionError
# Task exception was never retrieved
# future: <Task finished name='Task-37808' coro=<Server._handle_comm() done, defined at /home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py:740> exception=AssertionError()>
# Traceback (most recent call last):
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 834, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5984, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 917, in handle_stream
#     handler(**merge(extra, msg))
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5634, in stimulus_cancel
#     self.stimulus_cancel(
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5643, in stimulus_cancel
#     assert ts.who_wants
#            ^^^^^^^^^^^^
# AssertionError
# 2025-09-17 22:30:26,853 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:30:27,062 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:30:27,284 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:30:28,320 - distributed.core - ERROR - Exception while handling op register-client
# Traceback (most recent call last):
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 834, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5984, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 917, in handle_stream
#     handler(**merge(extra, msg))
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5634, in stimulus_cancel
#     self.stimulus_cancel(
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5643, in stimulus_cancel
#     assert ts.who_wants
#            ^^^^^^^^^^^^
# AssertionError
# Task exception was never retrieved
# ...
# Traceback (most recent call last):
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 834, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5984, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/core.py", line 917, in handle_stream
#     handler(**merge(extra, msg))
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5634, in stimulus_cancel
#     self.stimulus_cancel(
#   File "/home/riccorte/miniconda3/envs/dask-env/lib/python3.11/site-packages/distributed/scheduler.py", line 5643, in stimulus_cancel
#     assert ts.who_wants
#            ^^^^^^^^^^^^
# AssertionError
# 2025-09-17 22:31:18,116 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:31:18,320 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:31:18,527 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:31:18,742 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:31:19,006 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:31:19,218 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:31:19,998 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:31:23,936 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:31:24,168 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:31:24,385 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:31:24,625 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:31:24,825 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:31:25,041 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:31:25,285 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:31:25,496 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})
#
# 2025-09-17 22:31:25,715 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0) getitem(...)>
# new run_spec: Alias(('getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)->('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0))
# old dependencies: {('qr-2875cc9edd0fcae52737c4828dbd84df', 0, 0)}
# new dependencies: frozenset({('qr-getitem-2875cc9edd0fcae52737c4828dbd84df-r1', 0, 0)})

# %%
# check if everything went smoothly
cluster
# Out:
# LocalCluster(38a86131, 'tcp://127.0.0.1:44473', workers=4, threads=4, memory=5.79 GiB)

# %% [markdown]
# In the following, we download the California Housing dataset.
#
# Since our setup includes 4 VMs (1 master + 3 workers), and we plan to test performance with all possible numbers of workers (from 1 → 3), we select a fixed number of partitions equal to the least common multiple (LCM) of the worker counts.
# This ensures that the Dask environment can distribute the workload evenly and remain optimized across all the different cases, since an even divisibility is guaranteed and this the partitions are balanced across workers.

# %%
from sklearn.datasets import fetch_california_housing

# Download California Housing dataset
data = fetch_california_housing(as_frame=True)

# Convert features into Dask Array (it's a matrix).
n_partition = 6        
length_partition = data.data.shape[0] // n_partition
X_da = da.from_array(data.data.values, chunks=(length_partition, data.data.shape[1]))

print("Number of Dask partitions:",  X_da.npartitions) 
print("Length of each partition:", length_partition, "rows")
print("Length of the whole dataset:", data.data.shape[0], "rows")
# Out:
# Number of Dask partitions: 6
# Length of each partition: 3440 rows
# Length of the whole dataset: 20640 rows

# %% [markdown]
# Usually, to speed up computations, the dataset is persisted across workers. This way, subsequent functions can reuse the data directly from memory instead of re-reading it each time.
#
# In our case, however, the number of workers changes between runs. If we persist the data too early, it will remain pinned to the initial set of workers, and defining a new number of workers won't work properly. To avoid this imbalance, we only persist after deciding the number of workers for each run, ensuring that the dataset is distributed correctly across the active workers.

# %%
X_da
A0 = X_da

# %%
def ensure_scaled(target, timeout):  # Number of workers, timeout to avoid waiting in the event of an error
    """
    This is the function that scales the cluster to scale to `target` workers and wait until they are ready.

    """

    # Ask the scheduler to scale up to `target` workers.
    cluster.scale(target)

    t0 = time.time()

    # This loop calls the dask scheduler periodically until the number of workers desired are match or we have a timeout
    while time.time() - t0 < timeout:
        info = client.scheduler_info()
        nworkers = len(info.get("workers", {}))

        if nworkers >= target:
            # We have at least `target` workers and we can return the number of workers we will be working with
            return nworkers
        sleep(0.5)

    # If we exit the loop then the timeout was reached
    # Return the number of workers were available
    return len(client.scheduler_info().get("workers", {}))


def print_workers_info():
    """
    Important function to keep up with the diagnoscti information about each worker in the cluster.

    Useful if scaling failed or jobs are hanging.
    """
    info = client.scheduler_info().get("workers", {})
    for addr, w in info.items():
        # Show worker address, threads, number of tasks currently processing,
        # And the memory limit allocated to that worker.
        print(
            addr,
            "nthreads:", w.get("nthreads"),
            "processing:", len(w.get("processing", {})),
            "memory:", w.get("memory_limit")
        )




def run_once(A, tsqr_func, timeout = 120): # We receive the dask array with the imput matrix already persisted, and the function to use
    """
    This is the function that runs the TSQR functions and measure the execution time.

    """

    t0 = time.time()
    # We get Q, R. Depending on the function used they might be passed as a delayed object or a dask array.
    Q, R = tsqr_func(A)

  
    if hasattr(R, "persist"):   # In case R is also a Dask object it is necessary to persist it otherwise it would remain lazy
        R = R.persist()
        wait(R, timeout=timeout)
        client.cancel(R)    # Cancel after timing to free worker memory and ensure consistent conditions across different runs
    
    if hasattr(Q, "persist"):
        Q = Q.persist()
        wait(Q, timeout=timeout)
        client.cancel(Q)

    t1 = time.time()
    return t1 - t0

def time_vs_workers(workers_list, funcs, reps=2): # List of the number of workers to work with 
    """
    Run benchmarks for multiple TSQR algorithms across different worker counts.
    This is the function that iterates the run_once across all the different desired cases

    """

    results = {name: {} for name in funcs}  # nested dictionary

    for w in workers_list:
        # Ask cluster to scale and wait for workers by calling the previous function
        actual = ensure_scaled(w, timeout=120)
        print(f"\nRequested {w}, actual available {actual}")
        print_workers_info()

        # Rechunk to balance work across `actual` workers
        # The idea is to always have 6 partitions (balanced across workers later by scheduler)
        n_rows = int(A0.shape[0])
        rows_per_chunk = (n_rows + 6 - 1) // 6   # ceil division for 6 chunks

        A = A0.rechunk((rows_per_chunk, -1)).persist()  # This follows the number "initial" partitions that we initialized earlier

        # Wait until array is fully materialized in worker memory
        wait(A, timeout=120)


        # Benchmark each algorithm
        for name, func in funcs.items():    # This is the function that iterates over all the different TSQR algorithms:

            # Perform multiple timed runs
            times = [run_once(A, func) for _ in range(reps)]

            # Save mean and standard deviation
            results[name][w] = (float(np.mean(times)), float(np.std(times)))
            print(f"{name}, w={w}: mean={results[name][w][0]:.3f}s std={results[name][w][1]:.3f}s")

        # Cancel persisted array so next iteration starts clean
        client.cancel(A)
        del A

    return results  # Nested dictionary with structure results[algorithm][workers] = (mean_time, std_time).

# %% [markdown]
# The **results** show that, for a dataset of this size, changing the number of workers does not significantly affect efficiency. This is expected: when the dataset is small, the *computational load of a single worker is already manageable*, and the overhead introduced by distributing tasks across multiple workers can influence the potential speedup.
#
# Within this setup, the Cholesky TSQR emerges as the **most efficient method**, on the other hand the direct method performs slightly better than the indirect method. This behavior is strongly tied to the dataset size, and as it will be later shown: the direct method is advantageous with respect ot the indirect one only for smaller datasets.
#
# The reason of this changes stand in how the two approaches distribute and combine their computations:
#
# **Direct TSQR** requires each block to compute a local QR, followed by a second round of QR on the stacked intermediate R matrices. This creates a relatively large amount of intermediate data movement and synchronization. On small datasets this overhead is negligible, so the direct method performs well.
#
# **Indirect TSQR**, shifts more of the workload toward combining the much smaller R matrices. Its advantage is that the heavy computations (matrix multiplications with the global $R^{-1}$) scale better and avoid repeated QR decompositions. For small datasets this extra indirection is just overhead, but as the dataset grows, the relative cost of the QR steps in the direct method dominates, and the indirect method becomes more efficient.
#
#
#
# We can also experience that, for such a small dataset, the **standard deviation** of the runtimes can be relatively high and oscillate significantly across runs. This variability is mainly due to the fact that the computational load is so light that external factors (scheduling overhead, communication latency, or background processes on the machine) become comparable in magnitude to the actual computation time.

# %%
funcs = {
    "indirect": indirect_tsqr,
    "direct": direct_tsqr,
    "cholesky": cholesky_tsqr,
}

workers_list = [1, 2, 3]  # This is the list of workers you will run with, for the local case the maximum number of workers availble is 3
scaling_results = time_vs_workers(workers_list, funcs, reps=10)



# Plot the results
plt.figure(figsize=(8,6))
for name, data in scaling_results.items():
    ws = sorted(data.keys())
    means = [data[w][0] for w in ws]
    stds = [data[w][1] for w in ws]

    # Error bars show variance across repetitions
    plt.errorbar(ws, means, yerr=stds, marker="o", label=name)

plt.xlabel("Workers")
plt.ylabel("Time (s)")
plt.title("TSQR scaling comparison")
plt.xticks([int(w) for w in ws])
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Requested 1, actual available 3
# tcp://127.0.0.1:45607 nthreads: 1 processing: 0 memory: 1554740224
# tcp://127.0.0.1:46519 nthreads: 1 processing: 0 memory: 1554740224
# indirect, w=1: mean=0.349s std=0.157s
# direct, w=1: mean=0.197s std=0.038s
# cholesky, w=1: mean=0.102s std=0.018s
#
# Requested 2, actual available 2
# tcp://127.0.0.1:35855 nthreads: 1 processing: 0 memory: 1554740224
# tcp://127.0.0.1:46519 nthreads: 1 processing: 0 memory: 1554740224
# indirect, w=2: mean=0.260s std=0.080s
# direct, w=2: mean=0.163s std=0.017s
# cholesky, w=2: mean=0.097s std=0.008s
#
# Requested 3, actual available 3
# tcp://127.0.0.1:35347 nthreads: 1 processing: 0 memory: 1554740224
# tcp://127.0.0.1:35855 nthreads: 1 processing: 0 memory: 1554740224
# tcp://127.0.0.1:46519 nthreads: 1 processing: 0 memory: 1554740224
# indirect, w=3: mean=0.257s std=0.105s
# direct, w=3: mean=0.160s std=0.005s
# cholesky, w=3: mean=0.113s std=0.045s

# %% [markdown]
# Below we show a visualization of the Dask execution stream.
# (Note: the image corresponds to a simplified run compared to the full system shown above, to make the structure easier to follow)
#
# In the stream plot we can see how tasks such as compute_R, get item, matmul, read, etc. are scheduled and executed. These tasks are executed in parallel across the currently active workers.
#
# Once the computations for a given configuration of workers are finished, the cluster is rescaled and a new round of computations begins.
# As we have seen earlier the rescaling is achieved via the function `cluster.scale()`, which dynamically changes the number of active workers in the cluster. This allows us to test the same algorithms under different parallelization settings, without having to restart everything from scratch.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### New Clean Approach for SSH clusters:
#
# We will now apply the previously described method to the larger **HIGGS dataset**.
#
# Compared to the earlier setup, one complication arises: the `cluster.scale()` function does not behave properly with **SSH clusters**.
# This is because SSHCluster requires an explicit specification of workers at creation time. Workers cannot be dynamically scaled up or down with a simple integer argument, as this can corrupt the worker specification and lead to errors.
#
# To vary the number of workers, we therefore adopt a different approach:
# we repeatedly **stop and restart the cluster**, each time initializing it with a different number of workers.
# This allows us to systematically study performance while controlling the cluster size.

# %%
from dask.distributed import SSHCluster, get_client

# %%
import dask.dataframe as dd
import os

os.chdir("/home/ubuntu") 
path_HIGGS = os.getcwd() + "/datasets/HIGGS.csv"

df = dd.read_csv(path_HIGGS, header=None, blocksize="50MB")    # The block size is chosen accordingly to the previous benchmarking results
X_df = df.iloc[:, 1:] 
X_da = X_df.to_dask_array(lengths=True)   # We want it as a matrix (an array, that is)

# %%
print(X_da)
A0 = X_da.rechunk((1_000_000, -1))
A0 = X_da
# Out:
# dask.array<read-_to_string_dtype-values, shape=(11000000, 28), dtype=float64, chunksize=(68752, 28), chunktype=numpy.ndarray>

# %%
def run_once(A, tsqr_func, client, timeout=300): 
    """Run one TSQR variant once on A.
    Works even if functions return (Q, R) with mixed types or just R."""

    import time
    t0 = time.time()
    result = tsqr_func(A)

  
    Q, R = result
    if hasattr(R, "persist"):   # in case R is also a Dask object
        R = R.persist()
        wait(R, timeout=timeout)
        client.cancel(R)
    # Persist only if Dask objects
    if hasattr(Q, "persist"):
        Q = Q.persist()
        wait(Q, timeout=timeout)
        client.cancel(Q)

    t1 = time.time()
    return t1 - t0

# %% [markdown]
# Most of the following functions are directly ispired from the local approach with some modification to be coherent with the new method.

# %%
def rechunk_mb(A0, chunks_per_worker=3, target_mb=100):
    """
    Rechunk A0 so each chunk is ~100 MB and at least `chunks_per_worker`
    per active worker. Then persist and rebalance across workers.
    """
    nworkers = max(1, len(client.scheduler_info().get("workers", {})))  # Get the number of workers via client.scheduler_info()
    n_rows   = int(A0.shape[0])
    n_cols   = int(A0.shape[1])
    bpe      = np.dtype(A0.dtype).itemsize  # bytes per element, tells how many bytes one entry of the matrix takes in memory

    # compute how many rows ~50 MB corresponds to
    rows_for_100mb = max(1, (target_mb * 1024**2) // (n_cols * bpe)) # target_mb * 1024**2 = target chunk size in bytes (e.g. 100 MB), (n_cols * bpe) = memory taken by one row

    # ensure enough chunks for load balancing
    n_chunks   = (n_rows + rows_for_100mb - 1) // rows_for_100mb  # ceiling division, number of chunks to get eactly 50 mb
    rows_per_chunk = (n_rows + n_chunks - 1) // n_chunks # ceiling division, how many rows per chunk

    # rechunk, persist into worker memory, and rebalance across workers
    A = A0.rechunk((rows_per_chunk, -1)).persist()  # Similarly as before we persist only after the number of workers have been defined
    wait(A)
    client.rebalance([A])
    return A


def benchmark_funcs(A, reps=3):
    """
    Run each TSQR variant (indirect, direct, cholesky) on A
    and return mean + std of runtimes over `reps` repetitions.
    """
    results = {}
    funcs = {
        "indirect": indirect_tsqr,
        "direct": direct_tsqr,
        "cholesky": cholesky_tsqr,
    }
    for name, func in funcs.items():
        times = [run_once(A, func, client) for _ in range(reps)]
        results[name] = (np.mean(times), np.std(times))
    return results


def run_scaling_experiment(hosts, worker_counts, reps=2):
    """
    For each value in worker_counts:
      - create a new SSHCluster with that many workers,
      - rechunk A0 for ~50 MB chunks,
      - benchmark all TSQR variants,
      - record mean + std runtime.
    """
    scaling_results = { "indirect": [], "direct": [], "cholesky": [] }

    for w in worker_counts:
        print(f"\n=== Running with {w} workers ===")

        # new cluster for each worker count
        cluster = SSHCluster(
            hosts,
            connect_options={"known_hosts": None},
            remote_python="/home/ubuntu/miniconda3/bin/python",
            worker_options={"n_workers": w, "nthreads": 1},
            scheduler_options={"port": 8786, "dashboard_address": ":8797"},
        )
        global client   # so the client is global and not only available inside the function
        client = Client(cluster)

        # rebalance dataset across current workers
        A = rechunk_mb(A0, chunks_per_worker=3, target_mb=100)

        # run and store results
        results = benchmark_funcs(A, reps=reps)
        for name, (mean, std) in results.items():
            scaling_results[name].append((w, mean, std))

        # cleanup
        client.close()
        cluster.close()

    return scaling_results

# %% [markdown]
# We can observe that the function takes as an argument the number of workers to be used.
#
# This value does not directly correspond to the *exact* number of active workers.
# That's because when we define the clusters inside the function `run_scaling_experiment()`, the argument `n_workers` is internally multiplied by the number of available cores per machine.
#
# In our case, the Virtual Machine has **3 cores**, so the actual number of workers launched is always a multiple of 3.
# As a result, the benchmarking experiments are carried out on **3, 6, 9, and 12 active workers**.
#
#
#
# ------------------------------------------------------------------------------------------------------------------------------
#
# ### Results
#
# The final results align well with our expectations: the **indirect method** proves to be more efficient than the direct method when working with larger datasets.
# Moreover, we observe that the system overall exhibits **lower standard deviations**, as random fluctuations become less significant when computations are distributed over a larger workload.
#
# Another key point is the effect of parallelization: for large datasets such as **HIGGS (≈20 GB)**, increasing the number of workers clearly improves performance. This is because a higher degree of parallelization reduces the per-worker computational load and allows better utilization of resources.
#
# However, such improvements cannot continue indefinitely. If we were to hypothetically increase the number of workers beyond our current limit, performance would continue to improve only up to a certain point. Beyond that threshold, we would expect to hit an **asymptote**, where adding more workers no longer yields significant speedups. This was the case of the earlier in the local environment, where we almost had saturation.

# %%
hosts = ["10.67.22.154", "10.67.22.216", "10.67.22.116", "10.67.22.113"]
worker_counts = [1, 2, 3, 4]  
scaling_results = run_scaling_experiment(hosts, worker_counts, reps=20)


# Plot:
plt.figure(figsize=(8,5))
for name, data in scaling_results.items():
    ws, means, stds = zip(*data)
    ws_scaled = [int(w*3) for w in ws]   # multiply by 3 and cast to int
    plt.errorbar(ws_scaled, means, yerr=stds, marker="o", label=name)

plt.xlabel("Number of workers")
plt.ylabel("Time (s)")
plt.title("TSQR runtimes vs. workers")
plt.legend()
plt.grid(True)

# Force x-axis ticks to be exactly the scaled worker counts
plt.xticks([int(w*3) for w in ws])

plt.show()
# Out:
# === Running with 1 workers ===
# 2025-09-15 16:38:41,479 - distributed.deploy.ssh - INFO - 2025-09-15 16:38:41,479 - distributed.http.proxy - INFO - To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy
# 2025-09-15 16:38:41,500 - distributed.deploy.ssh - INFO - 2025-09-15 16:38:41,500 - distributed.scheduler - INFO - State start
# 2025-09-15 16:38:41,504 - distributed.deploy.ssh - INFO - 2025-09-15 16:38:41,504 - distributed.scheduler - INFO -   Scheduler at:   tcp://10.67.22.154:8786
# 2025-09-15 16:38:43,125 - distributed.deploy.ssh - INFO - 2025-09-15 16:38:43,125 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.113:46271'
# 2025-09-15 16:38:43,240 - distributed.deploy.ssh - INFO - 2025-09-15 16:38:43,243 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.116:42065'
# 2025-09-15 16:38:43,433 - distributed.deploy.ssh - INFO - 2025-09-15 16:38:43,432 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.216:38461'
# 2025-09-15 16:38:43,461 - distributed.deploy.ssh - INFO - 2025-09-15 16:38:43,461 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-a6hd6noa', purging
# 2025-09-15 16:38:43,462 - distributed.deploy.ssh - INFO - 2025-09-15 16:38:43,461 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-5teeuv6p', purging
# 2025-09-15 16:38:43,463 - distributed.deploy.ssh - INFO - 2025-09-15 16:38:43,461 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-ed0u_b7f', purging
# 2025-09-15 16:38:43,463 - distributed.deploy.ssh - INFO - 2025-09-15 16:38:43,462 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-vobq26jl', purging
# 2025-09-15 16:38:43,478 - distributed.deploy.ssh - INFO - 2025-09-15 16:38:43,478 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.113:40839
# 2025-09-15 16:38:43,588 - distributed.deploy.ssh - INFO - 2025-09-15 16:38:43,591 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-8dknq5ja', purging
# 2025-09-15 16:38:43,589 - distributed.deploy.ssh - INFO - 2025-09-15 16:38:43,592 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-ph72hhpn', purging
# 2025-09-15 16:38:43,589 - distributed.deploy.ssh - INFO - 2025-09-15 16:38:43,592 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-ga5qo46v', purging
# 2025-09-15 16:38:43,590 - distributed.deploy.ssh - INFO - 2025-09-15 16:38:43,593 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-8pzoe_wy', purging
# 2025-09-15 16:38:43,613 - distributed.deploy.ssh - INFO - 2025-09-15 16:38:43,616 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.116:34995
# 2025-09-15 16:38:43,847 - distributed.deploy.ssh - INFO - 2025-09-15 16:38:43,846 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-5cjgad_o', purging
# 2025-09-15 16:38:43,848 - distributed.deploy.ssh - INFO - 2025-09-15 16:38:43,846 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-ldu7rcfz', purging
# 2025-09-15 16:38:43,848 - distributed.deploy.ssh - INFO - 2025-09-15 16:38:43,847 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-k2ymfqvu', purging
# 2025-09-15 16:38:43,848 - distributed.deploy.ssh - INFO - 2025-09-15 16:38:43,847 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-ldkwoub7', purging
# 2025-09-15 16:38:43,866 - distributed.deploy.ssh - INFO - 2025-09-15 16:38:43,864 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.216:40161
# === Running with 2 workers ===
# 2025-09-15 16:46:35,401 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:35,401 - distributed.http.proxy - INFO - To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy
# 2025-09-15 16:46:35,420 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:35,420 - distributed.scheduler - INFO - State start
# 2025-09-15 16:46:35,424 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:35,423 - distributed.scheduler - INFO -   Scheduler at:   tcp://10.67.22.154:8786
# 2025-09-15 16:46:36,829 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:36,827 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.113:43019'
# 2025-09-15 16:46:36,831 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:36,829 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.113:43021'
# 2025-09-15 16:46:37,023 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,022 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.216:44879'
# 2025-09-15 16:46:37,026 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,025 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.216:44855'
# 2025-09-15 16:46:37,158 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,156 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-97cn548e', purging
# 2025-09-15 16:46:37,170 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,172 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.116:33491'
# 2025-09-15 16:46:37,172 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,175 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.116:44229'
# 2025-09-15 16:46:37,235 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,232 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.113:44229
# 2025-09-15 16:46:37,236 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,233 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.113:44229
# 2025-09-15 16:46:37,236 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,233 - distributed.worker - INFO -          dashboard at:         10.67.22.113:44133
# 2025-09-15 16:46:37,236 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,233 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.154:8786
# 2025-09-15 16:46:37,237 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,233 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:46:37,237 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,233 - distributed.worker - INFO -               Threads:                          1
# 2025-09-15 16:46:37,238 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,233 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2025-09-15 16:46:37,238 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,233 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-oknty7z4
# 2025-09-15 16:46:37,238 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,233 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:46:37,248 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,246 - distributed.worker - INFO - Starting Worker plugin shuffle
# 2025-09-15 16:46:37,249 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,247 - distributed.worker - INFO -         Registered to:    tcp://10.67.22.154:8786
# 2025-09-15 16:46:37,249 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,247 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:46:37,250 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,247 - distributed.core - INFO - Starting established connection to tcp://10.67.22.154:8786
# 2025-09-15 16:46:37,254 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,252 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.113:36961
# 2025-09-15 16:46:37,437 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,436 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-67e368uv', purging
# 2025-09-15 16:46:37,457 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,456 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.216:44083
# 2025-09-15 16:46:37,458 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,456 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.216:44083
# 2025-09-15 16:46:37,458 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,456 - distributed.worker - INFO -          dashboard at:         10.67.22.216:32813
# 2025-09-15 16:46:37,458 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,456 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.154:8786
# 2025-09-15 16:46:37,459 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,456 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:46:37,459 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,456 - distributed.worker - INFO -               Threads:                          1
# 2025-09-15 16:46:37,460 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,456 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2025-09-15 16:46:37,460 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,457 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-l4_4kort
# 2025-09-15 16:46:37,460 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,457 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:46:37,468 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,467 - distributed.worker - INFO - Starting Worker plugin shuffle
# 2025-09-15 16:46:37,468 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,467 - distributed.worker - INFO -         Registered to:    tcp://10.67.22.154:8786
# 2025-09-15 16:46:37,469 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,467 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:46:37,469 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,468 - distributed.core - INFO - Starting established connection to tcp://10.67.22.154:8786
# 2025-09-15 16:46:37,485 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,484 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.216:46579
# 2025-09-15 16:46:37,518 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,520 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-sj15zsja', purging
# 2025-09-15 16:46:37,541 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,543 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.116:37537
# 2025-09-15 16:46:37,541 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,543 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.116:37537
# 2025-09-15 16:46:37,542 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,543 - distributed.worker - INFO -          dashboard at:         10.67.22.116:43655
# 2025-09-15 16:46:37,542 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,543 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.154:8786
# 2025-09-15 16:46:37,542 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,543 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:46:37,543 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,543 - distributed.worker - INFO -               Threads:                          1
# 2025-09-15 16:46:37,543 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,543 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2025-09-15 16:46:37,543 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,543 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-_s1t0ik_
# 2025-09-15 16:46:37,543 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,543 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:46:37,550 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,553 - distributed.worker - INFO - Starting Worker plugin shuffle
# 2025-09-15 16:46:37,551 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,553 - distributed.worker - INFO -         Registered to:    tcp://10.67.22.154:8786
# 2025-09-15 16:46:37,551 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,553 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:46:37,551 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,553 - distributed.core - INFO - Starting established connection to tcp://10.67.22.154:8786
# 2025-09-15 16:46:37,603 - distributed.deploy.ssh - INFO - 2025-09-15 16:46:37,606 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.116:39011
# === Running with 3 workers ===
# 2025-09-15 16:51:12,168 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:12,168 - distributed.http.proxy - INFO - To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy
# 2025-09-15 16:51:12,189 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:12,188 - distributed.scheduler - INFO - State start
# 2025-09-15 16:51:12,192 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:12,192 - distributed.scheduler - INFO -   Scheduler at:   tcp://10.67.22.154:8786
# 2025-09-15 16:51:13,899 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:13,896 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.113:37291'
# 2025-09-15 16:51:13,901 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:13,899 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.113:42319'
# 2025-09-15 16:51:13,903 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:13,901 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.113:43911'
# 2025-09-15 16:51:13,956 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:13,958 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.116:41031'
# 2025-09-15 16:51:13,959 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:13,961 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.116:33437'
# 2025-09-15 16:51:13,960 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:13,963 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.116:38509'
# 2025-09-15 16:51:14,190 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,189 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.216:33721'
# 2025-09-15 16:51:14,193 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,192 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.216:37797'
# 2025-09-15 16:51:14,197 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,196 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.216:38227'
# 2025-09-15 16:51:14,236 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,233 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-oknty7z4', purging
# 2025-09-15 16:51:14,236 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,234 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-3dc8b28t', purging
# 2025-09-15 16:51:14,257 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,254 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.113:44085
# 2025-09-15 16:51:14,257 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,254 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.113:44085
# 2025-09-15 16:51:14,258 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,254 - distributed.worker - INFO -          dashboard at:         10.67.22.113:39007
# 2025-09-15 16:51:14,259 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,254 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.113:38985
# 2025-09-15 16:51:14,259 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,254 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.154:8786
# 2025-09-15 16:51:14,259 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,254 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:51:14,260 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,254 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.113:38985
# 2025-09-15 16:51:14,260 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,255 - distributed.worker - INFO -          dashboard at:         10.67.22.113:39567
# 2025-09-15 16:51:14,260 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,255 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.154:8786
# 2025-09-15 16:51:14,261 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,255 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:51:14,261 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,255 - distributed.worker - INFO -               Threads:                          1
# 2025-09-15 16:51:14,261 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,255 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2025-09-15 16:51:14,262 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,255 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-tawmnmb0
# 2025-09-15 16:51:14,262 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,255 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:51:14,262 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,254 - distributed.worker - INFO -               Threads:                          1
# 2025-09-15 16:51:14,263 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,255 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2025-09-15 16:51:14,263 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,255 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-erq9tqhi
# 2025-09-15 16:51:14,264 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,255 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:51:14,264 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,259 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.113:39797
# 2025-09-15 16:51:14,297 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,300 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-hsowqcv_', purging
# 2025-09-15 16:51:14,298 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,300 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-_s1t0ik_', purging
# 2025-09-15 16:51:14,318 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,320 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.116:45231
# 2025-09-15 16:51:14,319 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,320 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.116:45231
# 2025-09-15 16:51:14,319 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,320 - distributed.worker - INFO -          dashboard at:         10.67.22.116:35095
# 2025-09-15 16:51:14,319 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,320 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.116:34127
# 2025-09-15 16:51:14,320 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,320 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.154:8786
# 2025-09-15 16:51:14,321 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,320 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.116:34127
# 2025-09-15 16:51:14,322 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,320 - distributed.worker - INFO -          dashboard at:         10.67.22.116:41433
# 2025-09-15 16:51:14,322 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,320 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:51:14,322 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,321 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.154:8786
# 2025-09-15 16:51:14,323 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,321 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:51:14,323 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,320 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.116:34203
# 2025-09-15 16:51:14,631 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,630 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-r44d013l', purging
# 2025-09-15 16:51:14,632 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,630 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-l4_4kort', purging
# 2025-09-15 16:51:14,653 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,651 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.216:44943
# 2025-09-15 16:51:14,653 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,651 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.216:44943
# 2025-09-15 16:51:14,653 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,651 - distributed.worker - INFO -          dashboard at:         10.67.22.216:42681
# 2025-09-15 16:51:14,654 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,651 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.154:8786
# 2025-09-15 16:51:14,655 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,651 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:51:14,656 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,651 - distributed.worker - INFO -               Threads:                          1
# 2025-09-15 16:51:14,656 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,652 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2025-09-15 16:51:14,657 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,652 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-f0hp9r23
# 2025-09-15 16:51:14,657 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,652 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:51:14,657 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,652 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.216:41823
# 2025-09-15 16:51:14,658 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,652 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.216:41823
# 2025-09-15 16:51:14,658 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,653 - distributed.worker - INFO -          dashboard at:         10.67.22.216:33879
# 2025-09-15 16:51:14,658 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,653 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.154:8786
# 2025-09-15 16:51:14,659 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,653 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:51:14,659 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,653 - distributed.worker - INFO -               Threads:                          1
# 2025-09-15 16:51:14,659 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,653 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2025-09-15 16:51:14,659 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,653 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-7kignxqs
# 2025-09-15 16:51:14,660 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,653 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:51:14,664 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,663 - distributed.worker - INFO - Starting Worker plugin shuffle
# 2025-09-15 16:51:14,665 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,663 - distributed.worker - INFO -         Registered to:    tcp://10.67.22.154:8786
# 2025-09-15 16:51:14,665 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,664 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:51:14,666 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,664 - distributed.worker - INFO - Starting Worker plugin shuffle
# 2025-09-15 16:51:14,666 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,664 - distributed.core - INFO - Starting established connection to tcp://10.67.22.154:8786
# 2025-09-15 16:51:14,667 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,664 - distributed.worker - INFO -         Registered to:    tcp://10.67.22.154:8786
# 2025-09-15 16:51:14,667 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,664 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:51:14,667 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,665 - distributed.core - INFO - Starting established connection to tcp://10.67.22.154:8786
# 2025-09-15 16:51:14,679 - distributed.deploy.ssh - INFO - 2025-09-15 16:51:14,678 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.216:35831
# === Running with 4 workers ===
# 2025-09-15 16:54:46,263 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:46,262 - distributed.http.proxy - INFO - To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy
# 2025-09-15 16:54:46,283 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:46,283 - distributed.scheduler - INFO - State start
# 2025-09-15 16:54:46,287 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:46,287 - distributed.scheduler - INFO -   Scheduler at:   tcp://10.67.22.154:8786
# 2025-09-15 16:54:47,967 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:47,964 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.113:44877'
# 2025-09-15 16:54:47,969 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:47,967 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.113:35885'
# 2025-09-15 16:54:47,971 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:47,968 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.113:36999'
# 2025-09-15 16:54:47,973 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:47,970 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.113:41157'
# 2025-09-15 16:54:48,106 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,109 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.116:37899'
# 2025-09-15 16:54:48,109 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,112 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.116:43753'
# 2025-09-15 16:54:48,114 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,116 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.116:46657'
# 2025-09-15 16:54:48,115 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,118 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.116:41009'
# 2025-09-15 16:54:48,294 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,291 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-erq9tqhi', purging
# 2025-09-15 16:54:48,294 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,292 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-tawmnmb0', purging
# 2025-09-15 16:54:48,295 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,292 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-6chysibz', purging
# 2025-09-15 16:54:48,318 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.113:34571
# 2025-09-15 16:54:48,318 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.113:44505
# 2025-09-15 16:54:48,319 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.113:34571
# 2025-09-15 16:54:48,319 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO -          dashboard at:         10.67.22.113:42197
# 2025-09-15 16:54:48,320 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.113:43829
# 2025-09-15 16:54:48,320 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.113:44505
# 2025-09-15 16:54:48,320 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.154:8786
# 2025-09-15 16:54:48,321 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:48,321 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO -          dashboard at:         10.67.22.113:45395
# 2025-09-15 16:54:48,321 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.113:43829
# 2025-09-15 16:54:48,322 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.154:8786
# 2025-09-15 16:54:48,322 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO -          dashboard at:         10.67.22.113:38111
# 2025-09-15 16:54:48,322 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:48,323 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.154:8786
# 2025-09-15 16:54:48,323 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:48,323 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO -               Threads:                          1
# 2025-09-15 16:54:48,323 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2025-09-15 16:54:48,324 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO -               Threads:                          1
# 2025-09-15 16:54:48,324 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-egv7w1nl
# 2025-09-15 16:54:48,324 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2025-09-15 16:54:48,325 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-k1hondg4
# 2025-09-15 16:54:48,325 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:48,325 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:48,326 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO -               Threads:                          1
# 2025-09-15 16:54:48,326 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2025-09-15 16:54:48,326 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-oefp8tr7
# 2025-09-15 16:54:48,327 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,315 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:48,332 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,329 - distributed.worker - INFO - Starting Worker plugin shuffle
# 2025-09-15 16:54:48,332 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,329 - distributed.worker - INFO -         Registered to:    tcp://10.67.22.154:8786
# 2025-09-15 16:54:48,333 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,329 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:48,333 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,330 - distributed.worker - INFO - Starting Worker plugin shuffle
# 2025-09-15 16:54:48,334 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,330 - distributed.core - INFO - Starting established connection to tcp://10.67.22.154:8786
# 2025-09-15 16:54:48,334 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,330 - distributed.worker - INFO -         Registered to:    tcp://10.67.22.154:8786
# 2025-09-15 16:54:48,335 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,330 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:48,335 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,330 - distributed.worker - INFO - Starting Worker plugin shuffle
# 2025-09-15 16:54:48,336 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,330 - distributed.core - INFO - Starting established connection to tcp://10.67.22.154:8786
# 2025-09-15 16:54:48,337 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,330 - distributed.worker - INFO -         Registered to:    tcp://10.67.22.154:8786
# 2025-09-15 16:54:48,337 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,330 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:48,337 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,331 - distributed.core - INFO - Starting established connection to tcp://10.67.22.154:8786
# 2025-09-15 16:54:48,339 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,331 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.113:41121
# 2025-09-15 16:54:48,458 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,460 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-gohb73od', purging
# 2025-09-15 16:54:48,458 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,461 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-uaa8lya1', purging
# 2025-09-15 16:54:48,459 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,462 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-zl8ikwau', purging
# 2025-09-15 16:54:48,485 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,488 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.116:40277
# 2025-09-15 16:54:48,486 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,488 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.116:40277
# 2025-09-15 16:54:48,486 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,488 - distributed.worker - INFO -          dashboard at:         10.67.22.116:36527
# 2025-09-15 16:54:48,487 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,488 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.154:8786
# 2025-09-15 16:54:48,488 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,488 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:48,488 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,488 - distributed.worker - INFO -               Threads:                          1
# 2025-09-15 16:54:48,489 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,489 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2025-09-15 16:54:48,489 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,489 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-ln0enobc
# 2025-09-15 16:54:48,489 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,489 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:48,498 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,501 - distributed.worker - INFO - Starting Worker plugin shuffle
# 2025-09-15 16:54:48,499 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,501 - distributed.worker - INFO -         Registered to:    tcp://10.67.22.154:8786
# 2025-09-15 16:54:48,499 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,501 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:48,501 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,504 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.116:33383
# 2025-09-15 16:54:48,502 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,504 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.116:33383
# 2025-09-15 16:54:48,502 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,504 - distributed.worker - INFO -          dashboard at:         10.67.22.116:45729
# 2025-09-15 16:54:48,502 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,504 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.154:8786
# 2025-09-15 16:54:48,503 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,504 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:48,503 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,504 - distributed.worker - INFO -               Threads:                          1
# 2025-09-15 16:54:48,503 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,504 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2025-09-15 16:54:48,503 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,504 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-xfa5ptjq
# 2025-09-15 16:54:48,504 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,504 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:48,505 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,504 - distributed.core - INFO - Starting established connection to tcp://10.67.22.154:8786
# 2025-09-15 16:54:48,506 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,508 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.116:45923
# 2025-09-15 16:54:48,506 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,509 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.116:45923
# 2025-09-15 16:54:48,507 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,509 - distributed.worker - INFO -          dashboard at:         10.67.22.116:38197
# 2025-09-15 16:54:48,507 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,509 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.154:8786
# 2025-09-15 16:54:48,507 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,509 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:48,508 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,509 - distributed.worker - INFO -               Threads:                          1
# 2025-09-15 16:54:48,508 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,509 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2025-09-15 16:54:48,509 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,509 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-4euw52f4
# 2025-09-15 16:54:48,509 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,509 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:48,511 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,514 - distributed.worker - INFO - Starting Worker plugin shuffle
# 2025-09-15 16:54:48,512 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,514 - distributed.worker - INFO -         Registered to:    tcp://10.67.22.154:8786
# 2025-09-15 16:54:48,512 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,514 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:48,513 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,515 - distributed.core - INFO - Starting established connection to tcp://10.67.22.154:8786
# 2025-09-15 16:54:48,514 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,516 - distributed.worker - INFO - Starting Worker plugin shuffle
# 2025-09-15 16:54:48,514 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,517 - distributed.worker - INFO -         Registered to:    tcp://10.67.22.154:8786
# 2025-09-15 16:54:48,514 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,517 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:48,515 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,517 - distributed.core - INFO - Starting established connection to tcp://10.67.22.154:8786
# 2025-09-15 16:54:48,534 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:48,536 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.116:40441
# 2025-09-15 16:54:49,326 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,325 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.216:41213'
# 2025-09-15 16:54:49,336 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,335 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.216:36681'
# 2025-09-15 16:54:49,339 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,338 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.216:45653'
# 2025-09-15 16:54:49,342 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,341 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.216:40221'
# 2025-09-15 16:54:49,766 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,764 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-7kignxqs', purging
# 2025-09-15 16:54:49,766 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,765 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-j1zjoqb5', purging
# 2025-09-15 16:54:49,768 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,766 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-f0hp9r23', purging
# 2025-09-15 16:54:49,791 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,790 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.216:37543
# 2025-09-15 16:54:49,792 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,790 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.216:37543
# 2025-09-15 16:54:49,792 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,790 - distributed.worker - INFO -          dashboard at:         10.67.22.216:39371
# 2025-09-15 16:54:49,793 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,790 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.154:8786
# 2025-09-15 16:54:49,793 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,790 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:49,794 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,790 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.216:37967
# 2025-09-15 16:54:49,794 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,790 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.216:37967
# 2025-09-15 16:54:49,794 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,790 - distributed.worker - INFO -          dashboard at:         10.67.22.216:35411
# 2025-09-15 16:54:49,795 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,790 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.154:8786
# 2025-09-15 16:54:49,795 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,790 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:49,796 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,790 - distributed.worker - INFO -               Threads:                          1
# 2025-09-15 16:54:49,796 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,790 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2025-09-15 16:54:49,796 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,790 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-6iozpx31
# 2025-09-15 16:54:49,797 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,790 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:49,797 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,790 - distributed.worker - INFO -               Threads:                          1
# 2025-09-15 16:54:49,797 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,791 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2025-09-15 16:54:49,798 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,791 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-mzrsi710
# 2025-09-15 16:54:49,798 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,791 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:49,806 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,805 - distributed.worker - INFO - Starting Worker plugin shuffle
# 2025-09-15 16:54:49,807 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,806 - distributed.worker - INFO -         Registered to:    tcp://10.67.22.154:8786
# 2025-09-15 16:54:49,807 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,806 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:49,808 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,806 - distributed.worker - INFO - Starting Worker plugin shuffle
# 2025-09-15 16:54:49,808 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,806 - distributed.core - INFO - Starting established connection to tcp://10.67.22.154:8786
# 2025-09-15 16:54:49,808 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,806 - distributed.worker - INFO -         Registered to:    tcp://10.67.22.154:8786
# 2025-09-15 16:54:49,809 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,806 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:49,809 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,807 - distributed.core - INFO - Starting established connection to tcp://10.67.22.154:8786
# 2025-09-15 16:54:49,819 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,818 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.216:36117
# 2025-09-15 16:54:49,820 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,818 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.216:36117
# 2025-09-15 16:54:49,820 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,818 - distributed.worker - INFO -          dashboard at:         10.67.22.216:38363
# 2025-09-15 16:54:49,820 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,818 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.154:8786
# 2025-09-15 16:54:49,820 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,818 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:49,821 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,818 - distributed.worker - INFO -               Threads:                          1
# 2025-09-15 16:54:49,821 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,818 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2025-09-15 16:54:49,822 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,818 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-0uz9wie2
# 2025-09-15 16:54:49,822 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,818 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:49,828 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,827 - distributed.worker - INFO - Starting Worker plugin shuffle
# 2025-09-15 16:54:49,828 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,827 - distributed.worker - INFO -         Registered to:    tcp://10.67.22.154:8786
# 2025-09-15 16:54:49,829 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,827 - distributed.worker - INFO - -------------------------------------------------
# 2025-09-15 16:54:49,829 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,828 - distributed.core - INFO - Starting established connection to tcp://10.67.22.154:8786
# 2025-09-15 16:54:49,847 - distributed.deploy.ssh - INFO - 2025-09-15 16:54:49,846 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.216:37917

# %% [markdown]
# Here we can see the Dask dashboard while the function was running.
# As expected, the number of active workers changes dynamically and ranges from three up to twelve.
# Another interesting aspect is the **bytes stored per worker**: with only three workers, the memory usage per worker is significantly higher compared to the cases with more workers.
#
# <div style="display: flex; flex-wrap: wrap; justify-content: center; gap: 20px;">
#   <figure style="text-align: center;">
#     <img src="fig/workers_3_vm.PNG" width="400">
#     <figcaption>3 Workers</figcaption>
#   </figure>
#   <figure style="text-align: center;">
#     <img src="fig/workers_6_VM.PNG" width="400">
#     <figcaption>6 Workers</figcaption>
#   </figure>
#   <figure style="text-align: center;">
#     <img src="fig/workers_9_VM.PNG" width="400">
#     <figcaption>9 Workers</figcaption>
#   </figure>
#   <figure style="text-align: center;">
#     <img src="fig/workers_12_VM.PNG" width="400">
#     <figcaption>12 Workers</figcaption>
#   </figure>
# </div>

# %%
client.close()
